# %%
# %matplotlib inline
import pandas
import seaborn
import matplotlib.pyplot as plt

benchmarks = pandas.read_csv("./util.graph.GraphBench.csv")
benchmarks['Benchmark'] = benchmarks['Param: graph'].str.cat(benchmarks.Benchmark.str.extract('GraphBench.(.*)'), ' ')
seaborn.pointplot(ax=ax, x='Param: distance', y='Score', hue=benchmarks.Benchmark, data=benchmarks)
seaborn.axlabel('Seed distance', 'Score (ops/s)')
plt.show()

blockmatrix = pandas.read_csv("./src/test/resources/pprcd.py.graph-block-matrix.csv", header=None)
seaborn.heatmap(blockmatrix)
plt.show()

blocksize = pandas.read_csv("./src/test/resources/pprcd.py.graph-block-size.csv", header=None)
seaborn.categorical.barplot(data=blocksize)
plt.show()
# Out:
# /nix/store/g9q8cbq6qmx16nwq3ac171118126y7kk-python2.7-ipykernel-4.3.0/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
